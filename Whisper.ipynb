# %%
# !pip install git+https://github.com/openai/whisper.git
# !pip install ffmpeg
# !pip install torch torchaudio
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-mk377ft4
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-mk377ft4
#   Resolved https://github.com/openai/whisper.git to commit 517a43ecd132a2089d85f4ebc044728a71d49f6e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 38.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 63.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 53.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...

# %%
import whisper
model = whisper.load_model("small")
# Out:
# 100%|████████████████████████████████████████| 461M/461M [00:03<00:00, 143MiB/s]

# %%
# import sounddevice as sd
# from scipy.io.wavfile import write
# import numpy as np

# fs = 16000
# duration = 5
# print("Recording...")
# audio = sd.rec(int(fs * duration), samplerate=fs, channels=1, dtype=np.int16)
# sd.wait()
# write("recorded_audio.wav", fs, audio)
# print("Recording saved as 'recorded_audio.wav'")

# %%
from google.colab import files

uploaded = files.upload()
audio_file = list(uploaded.keys())[0]
print(f"Uploaded file: {audio_file}")
# Out:
#      <input type="file" id="files-cf60ba8e-3f68-4b03-8051-e289800e5946" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf60ba8e-3f68-4b03-8051-e289800e5946">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
result = model.transcribe(audio_file)
print("Transcription:", result["text"])
# Out:
# /usr/local/lib/python3.11/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ...

# %% [markdown]
# Is this a fracture ligament tear or a simple muscle strain 0:04 today we will explain the 4 imaging modalities commonly used after an injury 0:09 X-ray is a form of radiation it penetrates the body to produce an image 0:15 physiotherapists commonly use X-Ray to evaluate a possible fracture 0:20 dislocation and bone infection X-ray has many benefit it can be performed quickly 0:26 they are readily available and cost-effective the main limitation of X-ray 0:31 is it produces a 2 dimensional image of a 3 dimensional object 0:35 so a minimum of 2 different views are often required to evaluate the site of injury 0:41 CT scan fires a number of X-rays from different angles 0:45 it can produce a detailed cross-sectional image of the bone blood vessel and soft tissues 0:52 physiotherapists commonly use CT scan to evaluate complex regions of the body 0:57 these include the spine pelvis ankle and foot CT scan has many benefit 1:04 it can detect small fractures that may have been missed on a X-ray 1:08 it can also produce a 3 dimensional image which makes it easier to locate the site of injury 1:14 CT scan has many limitations it is relatively expensive 1:19 and compared to the plain X-ray it can expose the person to a greater amount of radiation 1:25 Ultrasound uses high-frequency sound waves to produce an image 1:29 physiotherapists commonly use ultrasound to evaluate soft tissues 1:33 such as the muscle tendon and ligament Ultrasound has many benefit 1:38 it does not expose the person to any radiation they are readily available cost-effective 1:44 and most importantly they can be performed during movement 1:48 this is particularly helpful in the evaluation of shoulder impingement 1:53 the main limitation of Ultrasound is it cannot penetrate the tissues 1:57 and produce image of deep structures such as the meniscus and the ACL 2:02 MRI uses strong magnets and radiofrequency waves to produce an image 2:07 physiotherapists commonly use MRI to evaluate the meniscus labrum spinal disc 2:13 joint and soft tissues MRI has many benefit it does not expose the person to any radiation 2:21 it provides detailed information about the body structures 2:24 this enables us to make accurate assessment of soft tissue injuries 2:29 MRI has many limitations it takes a lot longer to perform it is relatively expensive 2:35 and it cannot be performed in people with certain metal implants 2:38 as some metals can heat up or attract to the magnet 2:42 In summary X-ray and CT scan are often used to evaluate bony injuries such as fracture 2:49 MRI and ultrasound are often used to evaluate soft tissue injuries 2:54 including the muscle tendon and ligament 2:57 If you liked the content from today’s video don’t forget to subscribe 3:01 thank you for watching we will see you next time
